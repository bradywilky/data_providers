# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from ipynb.fs.full.data_pipeline import get_url, get_acled_dataframe

url = get_url(limit=1000000, notes='coronavirus')
df = get_acled_dataframe(url)

# %%
sources_list = list()
for s in df['source']:
    for i in s.split('; '):
        sources_list.append(i)

# %%
# First, we need a list of distinct sources
sources_distinct = list(set(sources_list))
sources_distinct_df = pd.DataFrame({'source_singular': sources_distinct})

# since eventually we're using a LIKE clause for the join, we need to add percentage wildcards here because we can't in pandasql.
sources_distinct_df['source_singular'] = sources_distinct_df['source_singular'].apply(lambda x: f'%{x}%')

# Second, join this df with the sources df with the help of pandasql

from pandasql import sqldf 
sql = lambda q: sqldf(q, globals())

expanded_source_df = sql('''
    SELECT * FROM df s
    JOIN sources_distinct_df sd
    ON s.source LIKE sd.source_singular
''')

# removing percentage wildcards
expanded_source_df['source_singular'] = expanded_source_df['source_singular'].apply(lambda x: x.replace('%', ''))
expanded_source_df.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 0  9491030  410      KOR25174            25174  2022-09-16  2022
# 1  9491038  156      CHN12137            12137  2022-09-15  2022
# 2  9491260  410      KOR25204            25204  2022-09-15  2022
# 3  9492137  250      FRA18626            18626  2022-09-15  2022
# 4  9493712  840      USA47753            47753  2022-09-15  2022
#
#   time_precision event_type    sub_event_type                      actor1  \
# 0              1   Protests  Peaceful protest    Protesters (South Korea)
# 1              1   Protests  Peaceful protest          Protesters (China)
# 2              1   Protests  Peaceful protest    Protesters (South Korea)
# 3              1   Protests  Peaceful protest         Protesters (France)
# 4              1   Protests  Peaceful protest  Protesters (United States)
#
#    ... latitude longitude geo_precision       source source_scale  \
# 0  ...  37.4744  127.0304             1       EDaily     National
# 1  ...  22.2811  114.1598             1         HK01  Subnational
# 2  ...  37.5223  126.9075             1          YNA     National
# 3  ...  43.2951   -0.3708             1  France Bleu     National
# 4  ...  40.7834  -73.9663             1     CBS News     National
#
#                                                notes fatalities   timestamp  \
# 0  On 16 September 2022, members of the All-Korea...          0  1663685720
# 1  On 15 September 2022, three representatives of...          0  1663685720
# 2  On 15 September 2022, members of the COVID-19 ...          0  1663685720
# 3  On 15 September 2022, around 30 opponents of c...          0  1663691322
# 4  On 15 September 2022, parents and students hel...          0  1663704952
#
#   iso3 source_singular
# 0  KOR          EDaily
# 1  CHN            HK01
# 2  KOR             YNA
# 3  FRA     France Bleu
# 4  USA        CBS News
#
# [5 rows x 32 columns]

# %%
expanded_source_df[expanded_source_df['source_singular'].str.len()<expanded_source_df['source'].str.len()]
# Out:
#         data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 8       9492040  276      DEU13144            13144  2022-09-12  2022
# 9       9492040  276      DEU13144            13144  2022-09-12  2022
# 14      9492163   40       AUT1180             1180  2022-09-10  2022
# 15      9466689  480        MUS297              297  2022-09-09  2022
# 16      9466689  480        MUS297              297  2022-09-09  2022
# ...         ...  ...           ...              ...         ...   ...
# 108703  8555697  408         PRK34               34  2020-01-24  2020
# 108704  7536939  156       CHN1378             1378  2020-01-23  2020
# 108705  7536939  156       CHN1378             1378  2020-01-23  2020
# 108706  8555702  408         PRK33               33  2020-01-22  2020
# 108707  8555702  408         PRK33               33  2020-01-22  2020
#
#        time_precision              event_type            sub_event_type  \
# 8                   1                Protests          Peaceful protest
# 9                   1                Protests          Peaceful protest
# 14                  1                Protests          Peaceful protest
# 15                  1                Protests          Peaceful protest
# 16                  1                Protests          Peaceful protest
# ...               ...                     ...                       ...
# 108703              1  Strategic developments  Change to group/activity
# 108704              1                Protests          Peaceful protest
# 108705              1                Protests          Peaceful protest
# 108706              1  Strategic developments  Change to group/activity
# 108707              1  Strategic developments  Change to group/activity
#
#                                    actor1  ...  latitude longitude  \
# 8                    Protesters (Germany)  ...   51.4831   11.9737
# 9                    Protesters (Germany)  ...   51.4831   11.9737
# 14                   Protesters (Austria)  ...   48.2088   16.3702
# 15                 Protesters (Mauritius)  ...  -10.3871   56.6179
# 16                 Protesters (Mauritius)  ...  -10.3871   56.6179
# ...                                   ...  ...       ...       ...
# 108703  Government of North Korea (2011-)  ...   39.0392  125.7625
# 108704                 Protesters (China)  ...   22.3201  114.1692
# 108705                 Protesters (China)  ...   22.3201  114.1692
# 108706  Government of North Korea (2011-)  ...   39.0392  125.7625
# 108707  Government of North Korea (2011-)  ...   39.0392  125.7625
#
#        geo_precision                                             source  \
# 8                  1  Mitteldeutschen Zeitung; Mitteldeutscher Rundfunk
# 9                  1  Mitteldeutschen Zeitung; Mitteldeutscher Rundfunk
# 14                 1              Heute - Osterreichs Neue Tageszeitung
# 15                 2    Le Mauricien; Defi Media; L'Express (Mauritius)
# 16                 2    Le Mauricien; Defi Media; L'Express (Mauritius)
# ...              ...                                                ...
# 108703             3                                   KBS; NK Pro; VOA
# 108704             1                                         RTHK; HK01
# 108705             1                                         RTHK; HK01
# 108706             3                                        NK Pro; YNA
# 108707             3                                        NK Pro; YNA
#
#           source_scale                                              notes  \
# 8             National  On 12 September 2022, around 850 people demons...
# 9             National  On 12 September 2022, around 850 people demons...
# 14            National  On 10 September 2022, around 3,000 people, inc...
# 15            National  On 9 September 2022, a group of people from Ag...
# 16            National  On 9 September 2022, a group of people from Ag...
# ...                ...                                                ...
# 108703  Other-Regional  On 24 January 2020, North Korea cancelled mult...
# 108704     Subnational  On 23 January 2020, 16 district councillors fr...
# 108705     Subnational  On 23 January 2020, 16 district councillors fr...
# 108706  Other-Regional  On 22 January 2020, the Government of North Ko...
# 108707  Other-Regional  On 22 January 2020, the Government of North Ko...
#
#        fatalities   timestamp iso3           source_singular
# 8               0  1663691322  DEU   Mitteldeutschen Zeitung
# 9               0  1663691322  DEU  Mitteldeutscher Rundfunk
# 14              0  1663691322  AUT                       ERR
# 15              0  1663026144  MUS              Le Mauricien
# 16              0  1663026144  MUS                 L'Express
# ...           ...         ...  ...                       ...
# 108703          0  1632239616  PRK                    NK Pro
# 108704          0  1611094728  CHN                      RTHK
# 108705          0  1611094728  CHN                      HK01
# 108706          0  1632239616  PRK                    NK Pro
# 108707          0  1632239616  PRK                       YNA
#
# [58198 rows x 32 columns]
