# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/acled_covid19.csv')

# %%
# First, we get a collective list of sources
sources_list = list()
for s in df['source']:
    for i in s.split(';'):
        sources_list.append(i.strip())

# %%
# From our collective list of sources we need a pandas DataFrame of distinct sources
sources_distinct = list(set(sources_list))
sources_distinct_df = pd.DataFrame({'source_singular': sources_distinct})

# since eventually we're using a LIKE clause for the join, we need to add percentage wildcards around each distinct source
# here in our pandas DataFrame, because we can't in pandasql.
sources_distinct_df['source_singular'] = sources_distinct_df['source_singular'].apply(lambda x: f'%{x}%')

# Second, join this distinct source df with the main df. I prefer using pandasql because of the like clause.
from pandasql import sqldf
sql = lambda q: sqldf(q, globals())

expanded_source_df = sql(
'''
    SELECT * FROM df main
    JOIN sources_distinct_df dst_src
    ON main.source LIKE dst_src.source_singular
'''
)

# We can now remove the percentage wildcards from the source_singular column, since we only needed them for the previous step.
expanded_source_df['source_singular'] = expanded_source_df['source_singular'].apply(lambda x: x.replace('%', ''))
expanded_source_df.head()
# Out:
#    Unnamed: 0  data_id  iso event_id_cnty  event_id_no_cnty  event_date  year  \
# 0           0  9498574  862      VEN12964             12964  2022-09-17  2022
# 1           1  9491030  410      KOR25174             25174  2022-09-16  2022
# 2           2  9491038  156      CHN12137             12137  2022-09-15  2022
# 3           3  9491260  410      KOR25204             25204  2022-09-15  2022
# 4           4  9492137  250      FRA18626             18626  2022-09-15  2022
#
#    time_precision event_type    sub_event_type  ... latitude longitude  \
# 0               1   Protests  Peaceful protest  ...   8.1292  -63.5409
# 1               1   Protests  Peaceful protest  ...  37.4744  127.0304
# 2               1   Protests  Peaceful protest  ...  22.2811  114.1598
# 3               1   Protests  Peaceful protest  ...  37.5223  126.9075
# 4               1   Protests  Peaceful protest  ...  43.2951   -0.3708
#
#    geo_precision           source source_scale  \
# 0              1  Diario Primicia  Subnational
# 1              1           EDaily     National
# 2              1             HK01  Subnational
# 3              1              YNA     National
# 4              1      France Bleu     National
#
#                                                notes  fatalities   timestamp  \
# 0  On 17 September 2022, in Ciudad Bolivar (Boliv...           0  1664226314
# 1  On 16 September 2022, members of the All-Korea...           0  1663685720
# 2  On 15 September 2022, three representatives of...           0  1663685720
# 3  On 15 September 2022, members of the COVID-19 ...           0  1663685720
# 4  On 15 September 2022, around 30 opponents of c...           0  1663691322
#
#   iso3  source_singular
# 0  VEN  Diario Primicia
# 1  KOR           EDaily
# 2  CHN             HK01
# 3  KOR              YNA
# 4  FRA      France Bleu
#
# [5 rows x 33 columns]

# %%
expanded_source_df[expanded_source_df['source_singular'].str.len()<expanded_source_df['source'].str.len()]
# Out:
#         Unnamed: 0  data_id  iso event_id_cnty  event_id_no_cnty  event_date  \
# 9                9  9492040  276      DEU13144             13144  2022-09-12
# 10               9  9492040  276      DEU13144             13144  2022-09-12
# 14              13  9492163   40       AUT1180              1180  2022-09-10
# 16              14  9466689  480        MUS297               297  2022-09-09
# 17              14  9466689  480        MUS297               297  2022-09-09
# ...            ...      ...  ...           ...               ...         ...
# 110176        1922  8873745  380        ITA521               521  2020-02-06
# 110178        1925  8873632  380        ITA473               473  2020-02-02
# 110179        1925  8873632  380        ITA473               473  2020-02-02
# 110180        1925  8873632  380        ITA473               473  2020-02-02
# 110182        1927  8884917  380        ITA452               452  2020-02-01
#
#         year  time_precision event_type    sub_event_type  ... latitude  \
# 9       2022               1   Protests  Peaceful protest  ...  51.4831
# 10      2022               1   Protests  Peaceful protest  ...  51.4831
# 14      2022               1   Protests  Peaceful protest  ...  48.2088
# 16      2022               1   Protests  Peaceful protest  ... -10.3871
# 17      2022               1   Protests  Peaceful protest  ... -10.3871
# ...      ...             ...        ...               ...  ...      ...
# 110176  2020               1   Protests  Peaceful protest  ...  45.8115
# 110178  2020               1   Protests  Peaceful protest  ...  45.4613
# 110179  2020               1   Protests  Peaceful protest  ...  45.4613
# 110180  2020               1   Protests  Peaceful protest  ...  45.4613
# 110182  2020               1      Riots      Mob violence  ...  44.7818
#
#        longitude  geo_precision  \
# 9        11.9737              1
# 10       11.9737              1
# 14       16.3702              1
# 16       56.6179              2
# 17       56.6179              2
# ...          ...            ...
# 110176    9.0829              1
# 110178    9.1595              1
# 110179    9.1595              1
# 110180    9.1595              1
# 110182   10.3292              1
#
#                                                    source  \
# 9       Mitteldeutschen Zeitung; Mitteldeutscher Rundfunk
# 10      Mitteldeutschen Zeitung; Mitteldeutscher Rundfunk
# 14                  Heute - Osterreichs Neue Tageszeitung
# 16        Le Mauricien; Defi Media; L'Express (Mauritius)
# 17        Le Mauricien; Defi Media; L'Express (Mauritius)
# ...                                                   ...
# 110176                             Varese7press; Qui Como
# 110178                        Milano Today; La Repubblica
# 110179                        Milano Today; La Repubblica
# 110180                        Milano Today; La Repubblica
# 110182                                        Parma Today
#
#                 source_scale  \
# 9                   National
# 10                  National
# 14                  National
# 16                  National
# 17                  National
# ...                      ...
# 110176           Subnational
# 110178  Subnational-National
# 110179  Subnational-National
# 110180  Subnational-National
# 110182           Subnational
#
#                                                     notes  fatalities  \
# 9       On 12 September 2022, around 850 people demons...           0
# 10      On 12 September 2022, around 850 people demons...           0
# 14      On 10 September 2022, around 3,000 people, inc...           0
# 16      On 9 September 2022, a group of people from Ag...           0
# 17      On 9 September 2022, a group of people from Ag...           0
# ...                                                   ...         ...
# 110176  On 6 February 2020, about 50 people, including...           0
# 110178  On 2 February 2020, around 100 people, most of...           0
# 110179  On 2 February 2020, around 100 people, most of...           0
# 110180  On 2 February 2020, around 100 people, most of...           0
# 110182  On 1 February 2020, several youngsters physica...           0
#
#          timestamp iso3           source_singular
# 9       1663691322  DEU  Mitteldeutscher Rundfunk
# 10      1663691322  DEU   Mitteldeutschen Zeitung
# 14      1663691322  AUT                       ERR
# 16      1663026144  MUS                Defi Media
# 17      1663026144  MUS              Le Mauricien
# ...            ...  ...                       ...
# 110176  1646327097  ITA              Varese7press
# 110178  1646327097  ITA              Milano Today
# 110179  1646327097  ITA                     Today
# 110180  1646327097  ITA             La Repubblica
# 110182  1646327171  ITA                     Today
#
# [59235 rows x 33 columns]

# %%
expanded_source_df[expanded_source_df['source_singular'] == 'ERR']
# Out:
#         Unnamed: 0  data_id  iso event_id_cnty  event_id_no_cnty  event_date  \
# 14              13  9492163   40       AUT1180              1180  2022-09-10
# 224            138  9439806   40       AUT1159              1159  2022-08-01
# 228            139  9439807   40       AUT1162              1162  2022-08-01
# 235            142  9440001   40       AUT1160              1160  2022-08-01
# 238            143  9440002   40       AUT1161              1161  2022-08-01
# ...            ...      ...  ...           ...               ...         ...
# 104036       61669  8382459  380       ITA1017              1017  2020-04-06
# 105538       62590  7818055   40         AUT87                87  2020-03-29
# 106566       63231  9416160  694       SIE4825              4825  2020-03-24
# 108116       64103  8874994  380        ITA937               937  2020-03-09
# 108877          61  8837497  840      USA39015             39015  2022-02-07
#
#         year  time_precision                  event_type  \
# 14      2022               1                    Protests
# 224     2022               1                    Protests
# 228     2022               1                    Protests
# 235     2022               1                    Protests
# 238     2022               1                    Protests
# ...      ...             ...                         ...
# 104036  2020               1  Violence against civilians
# 105538  2020               1                    Protests
# 106566  2020               1      Strategic developments
# 108116  2020               1                       Riots
# 108877  2022               1                    Protests
#
#                   sub_event_type  ... latitude longitude  geo_precision  \
# 14              Peaceful protest  ...  48.2088   16.3702              1
# 224             Peaceful protest  ...  47.0711   15.4383              1
# 228             Peaceful protest  ...  48.1566   14.0246              1
# 235             Peaceful protest  ...  48.3061   14.2857              1
# 238             Peaceful protest  ...  48.0391   14.4194              1
# ...                          ...  ...      ...       ...            ...
# 104036                    Attack  ...  41.0800   14.2566              1
# 105538          Peaceful protest  ...  48.2085   16.3721              1
# 106566  Change to group/activity  ...   8.4871  -13.2356              3
# 108116     Violent demonstration  ...  41.9376   12.5660              1
# 108877          Peaceful protest  ...  44.0760 -103.2280              1
#
#                                                    source  \
# 14                  Heute - Osterreichs Neue Tageszeitung
# 224                    Radio Osterreich 1; Kleine Zeitung
# 228                             Radio Osterreich 1; Krone
# 235                                    Radio Osterreich 1
# 238                                    Radio Osterreich 1
# ...                                                   ...
# 104036         In Terris; Osservatorio Repressione; Today
# 105538  Heute - Osterreichs Neue Tageszeitung; Indymed...
# 106566  Sierra Leone Telegraph; Cocorioko; Xinhua; Sie...
# 108116  Roma Today; Blitz Quotidiano; In Terris; Italp...
# 108877    Rapid City Journal; NewsCenter1; KOTA Territory
#
#                 source_scale  \
# 14                  National
# 224                 National
# 228                 National
# 235                 National
# 238                 National
# ...                      ...
# 104036        Other-National
# 105538        Other-National
# 106566    New media-National
# 108116  Subnational-National
# 108877           Subnational
#
#                                                     notes  fatalities  \
# 14      On 10 September 2022, around 3,000 people, inc...           0
# 224     On 1 August 2022, at the call of The Greens, a...           0
# 228     On 1 August 2022, around 150 people demonstrat...           0
# 235     On 1 August 2022, nearly 300 people demonstrat...           0
# 238     On 1 August 2022, people demonstrated in Steyr...           0
# ...                                                   ...         ...
# 104036  On 6 April 2020, a group of prison guards beat...           0
# 105538  On 29 March 2020, around 30 masked people gath...           0
# 106566  On 24 March 2020, the government of Sierra Leo...           0
# 108116  On 9 March 2020, hundreds of inmates detained ...           0
# 108877  On 7 February 2022, dozens of people, includin...           0
#
#          timestamp iso3 source_singular
# 14      1663691322  AUT             ERR
# 224     1660057400  AUT             ERR
# 228     1660057400  AUT             ERR
# 235     1660057401  AUT             ERR
# 238     1660057401  AUT             ERR
# ...            ...  ...             ...
# 104036  1626210401  ITA             ERR
# 105538  1618442048  AUT             ERR
# 106566  1658253392  SLE             ERR
# 108116  1646327101  ITA             ERR
# 108877  1644954289  USA             ERR
#
# [398 rows x 33 columns]
