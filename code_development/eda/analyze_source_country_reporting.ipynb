# %% [markdown]
# Because we're trying to look at the data in the context of usage, our focus is on how ACLED is using the information from souces to tag the data. One way of looking at this is to see if ACLED is using sources that are reporting on more than one country. The idea is that events can be tagged on if the source is known to report on multiple countries or not.

# %%
import pandas as pd

from pandasql import sqldf

sql = lambda q: sqldf(q, globals())

base_df = pd.read_csv('../data/acled_covid19.csv')
extd_df = pd.read_csv('../data/EXPANDED_acled_covid19.csv')

# %% [markdown]
# Here we obtain a count of how many distinct countries each source used in the ACLED dataset is reporting on.

# %%
df = sql('''
SELECT source_singular, count(*) country_count FROM
    (SELECT DISTINCT source_singular, country
    FROM extd_df) a
    GROUP BY source_singular
''')

print(f'{len(df[df.country_count > 1])} out of {len(df)} sources report on multiple countries.')
df[df.country_count > 1]
# Out:
# 297 out of 5362 sources report on multiple countries.
#      source_singular  country_count
# 26         168 Hours              2
# 33        20 Minutes              2
# 42         24 Heures              3
# 44          24 Horas              2
# 79           7 Sur 7              2
# ...              ...            ...
# 5276             YNA              2
# 5279        Yabiladi              3
# 5281      Yahoo News              4
# 5302            Ynet              2
# 5313         Youtube              6
#
# [297 rows x 2 columns]

# %% [markdown]
# We can see here that some sources do in fact report in multiple countries. Let's try and figure out if these countries are geographically close to each other. To do that, we can check if the sources are reporting from multiple regions as well.

# %%
multi_cntry_src_df = df[df.country_count > 1]

df2 = sql('''
SELECT source_singular, count(*) region_count FROM
    (SELECT DISTINCT main.source_singular, main.region
    FROM extd_df main
    JOIN multi_cntry_src_df m ON m.source_singular = main.source_singular
    ) a
    GROUP BY source_singular
''')

print(f'{len(df2[df2.region_count > 1])} out of {len(multi_cntry_src_df)} sources that report on multiple countries are also reporting in multiple regions.')
df2[df2.region_count > 1]
# Out:
# 96 out of 297 sources that report on multiple countries are also reporting in multiple regions.
#               source_singular  region_count
# 1                  20 Minutes             2
# 2                   24 Heures             2
# 3                    24 Horas             2
# 4                     7 Sur 7             2
# 6                         AFP            13
# ..                        ...           ...
# 289  World Socialist Web Site             2
# 291                    Xinhua             7
# 293                  Yabiladi             2
# 294                Yahoo News             3
# 296                   Youtube             4
#
# [96 rows x 2 columns]

# %%
count_df = sql('''
SELECT a.source_singular, country_count, region_count
FROM df a JOIN df2 b ON a.source_singular = b.source_singular
''')
count_df
# Out:
#     source_singular  country_count  region_count
# 0         168 Hours              2             1
# 1        20 Minutes              2             2
# 2         24 Heures              3             2
# 3          24 Horas              2             2
# 4           7 Sur 7              2             2
# ..              ...            ...           ...
# 292             YNA              2             1
# 293        Yabiladi              3             2
# 294      Yahoo News              4             3
# 295            Ynet              2             1
# 296         Youtube              6             4
#
# [297 rows x 3 columns]

# %%
src_ctry_df = sql('''

    SELECT source_singular, group_concat(country) countries FROM (
        SELECT DISTINCT a.source_singular, a.country FROM extd_df a
        JOIN count_df b
            ON a.source_singular = b.source_singular
        ) a
    GROUP BY a.source_singular
''')
src_ctry_df
# Out:
#     source_singular                                          countries
# 0         168 Hours                                 Azerbaijan,Armenia
# 1        20 Minutes                                  France,Martinique
# 2         24 Heures                          France,Switzerland,Canada
# 3          24 Horas                                      Mexico,Angola
# 4           7 Sur 7               Belgium,Democratic Republic of Congo
# ..              ...                                                ...
# 292             YNA                            South Korea,North Korea
# 293        Yabiladi                              Morocco,Spain,Algeria
# 294      Yahoo News                United States,Japan,Sri Lanka,India
# 295            Ynet                                   Israel,Palestine
# 296         Youtube  United States,New Zealand,Italy,Denmark,United...
#
# [297 rows x 2 columns]

# %%
src_rgn_df = sql('''
    SELECT source_singular, group_concat(region) regions FROM (
        SELECT DISTINCT a.source_singular, a.region FROM extd_df a
        JOIN count_df b
            ON a.source_singular = b.source_singular
        WHERE b.region_count > 1
        ) a
    GROUP BY a.source_singular
''')
src_rgn_df
# Out:
#              source_singular  \
# 0                 20 Minutes
# 1                  24 Heures
# 2                   24 Horas
# 3                    7 Sur 7
# 4                        AFP
# ..                       ...
# 91  World Socialist Web Site
# 92                    Xinhua
# 93                  Yabiladi
# 94                Yahoo News
# 95                   Youtube
#
#                                               regions
# 0                                    Caribbean,Europe
# 1                                Europe,North America
# 2                         Middle Africa,North America
# 3                                Europe,Middle Africa
# 4   Caribbean,Caucasus and Central Asia,Central Am...
# ..                                                ...
# 91                           North America,South Asia
# 92  Caucasus and Central Asia,East Asia,Europe,Mid...
# 93                             Europe,Northern Africa
# 94                 East Asia,North America,South Asia
# 95             East Asia,Europe,North America,Oceania
#
# [96 rows x 2 columns]

# %%
sql('''
    SELECT source_singular,countries FROM (
        SELECT source_singular, group_concat(country) countries FROM (
            SELECT DISTINCT a.source_singular, a.country FROM extd_df a
            JOIN count_df b
                ON a.source_singular = b.source_singular
            ) a
        GROUP BY a.source_singular
        ) b
        WHERE countries LIKE '%United States%'
''')
# Out:
#                  source_singular  \
# 0                             AP
# 1            Albanian Daily News
# 2                       BBC News
# 3                      CITY News
# 4                           CNBC
# 5                            CNN
# 6                      Daily Kos
# 7                     Daily Mail
# 8    Daily Mail (United Kingdom)
# 9                  Dominion Post
# 10                   Epoch Times
# 11                      EuroNews
# 12                      Facebook
# 13                      Guardian
# 14     Guardian (United Kingdom)
# 15                       Haaretz
# 16                    Herald Sun
# 17  Independent (United Kingdom)
# 18                     Instagram
# 19                     Intercept
# 20                Jerusalem Post
# 21                     Live Mint
# 22                     Liveuamap
# 23                      MSN News
# 24                New York Times
# 25                       Newsday
# 26                Republic World
# 27                       Reuters
# 28                       Twitter
# 29                          Vice
# 30               Washington Post
# 31      World Socialist Web Site
# 32                    Yahoo News
# 33                       Youtube
#
#                                             countries
# 0   North Korea,Tonga,Guadeloupe,Romania,Greece,Uk...
# 1                               Albania,United States
# 2   Iran,United Kingdom,Guatemala,Cuba,India,Leban...
# 3                                Canada,United States
# 4                             Indonesia,United States
# 5                    United States,Philippines,Israel
# 6                                Canada,United States
# 7                        United States,United Kingdom
# 8                        United States,United Kingdom
# 9                           New Zealand,United States
# 10                                China,United States
# 11                              Albania,United States
# 12  United States,Morocco,Italy,France,Philippines...
# 13                New Zealand,Australia,United States
# 14  Australia,United Kingdom,United States,Uganda,...
# 15                     Israel,Palestine,United States
# 16                            Australia,United States
# 17                       United Kingdom,United States
# 18                        Bahrain,United States,Italy
# 19                         United States,Burkina Faso
# 20                Israel,Iran,United States,Palestine
# 21                                India,United States
# 22  China,United States,Ukraine,Iraq,Afghanistan,I...
# 23                                Italy,United States
# 24  China,United States,Tonga,New Zealand,Afghanis...
# 25                  United States,Trinidad and Tobago
# 26                                United States,India
# 27  United States,Iran,Gabon,United Kingdom,Kazakh...
# 28  France,Canada,United States,Australia,China,Ne...
# 29                               Canada,United States
# 30                         United States,Canada,Kenya
# 31                            United States,Sri Lanka
# 32                United States,Japan,Sri Lanka,India
# 33  United States,New Zealand,Italy,Denmark,United...

# %%
# QUESTION
# should we be answering the question "This source that ACLED used for this event ________"
# 
#     ex: "The source ACLED used for information on this event is the most commonly used source associated with violent events"
#         "The source ACLED used for information on this event has not been used since DD-MM-YYYY"
base_df['sourc']
# Out:
#        Unnamed: 0  data_id  iso event_id_cnty  event_id_no_cnty  event_date  \
# 0               0  9498574  862      VEN12964             12964  2022-09-17
# 1               1  9491030  410      KOR25174             25174  2022-09-16
# 2               2  9491038  156      CHN12137             12137  2022-09-15
# 3               3  9491260  410      KOR25204             25204  2022-09-15
# 4               4  9492137  250      FRA18626             18626  2022-09-15
# ...           ...      ...  ...           ...               ...         ...
# 65101        1922  8873745  380        ITA521               521  2020-02-06
# 65102        1924  9441128  380        ITA477               477  2020-02-03
# 65103        1925  8873632  380        ITA473               473  2020-02-02
# 65104        1926  9441129  380        ITA468               468  2020-02-02
# 65105        1927  8884917  380        ITA452               452  2020-02-01
#
#        year  time_precision event_type    sub_event_type  ...  \
# 0      2022               1   Protests  Peaceful protest  ...
# 1      2022               1   Protests  Peaceful protest  ...
# 2      2022               1   Protests  Peaceful protest  ...
# 3      2022               1   Protests  Peaceful protest  ...
# 4      2022               1   Protests  Peaceful protest  ...
# ...     ...             ...        ...               ...  ...
# 65101  2020               1   Protests  Peaceful protest  ...
# 65102  2020               1   Protests  Peaceful protest  ...
# 65103  2020               1   Protests  Peaceful protest  ...
# 65104  2020               1   Protests  Peaceful protest  ...
# 65105  2020               1      Riots      Mob violence  ...
#
#                               location latitude  longitude geo_precision  \
# 0                       Ciudad Bolivar   8.1292   -63.5409             1
# 1                  Seoul City - Seocho  37.4744   127.0304             1
# 2      Hong Kong - Central and Western  22.2811   114.1598             1
# 3            Seoul City - Yeongdeungpo  37.5223   126.9075             1
# 4                                  Pau  43.2951    -0.3708             1
# ...                                ...      ...        ...           ...
# 65101                             Como  45.8115     9.0829             1
# 65102                    Busto Arsizio  45.6054     8.8434             1
# 65103                           Milano  45.4613     9.1595             1
# 65104                          Brescia  45.5354    10.2236             1
# 65105                            Parma  44.7818    10.3292             1
#
#                             source          source_scale  \
# 0                  Diario Primicia           Subnational
# 1                           EDaily              National
# 2                             HK01           Subnational
# 3                              YNA              National
# 4                      France Bleu              National
# ...                            ...                   ...
# 65101       Varese7press; Qui Como           Subnational
# 65102                   Malpensa24              National
# 65103  Milano Today; La Repubblica  Subnational-National
# 65104                     Rai News              National
# 65105                  Parma Today           Subnational
#
#                                                    notes fatalities  \
# 0      On 17 September 2022, in Ciudad Bolivar (Boliv...          0
# 1      On 16 September 2022, members of the All-Korea...          0
# 2      On 15 September 2022, three representatives of...          0
# 3      On 15 September 2022, members of the COVID-19 ...          0
# 4      On 15 September 2022, around 30 opponents of c...          0
# ...                                                  ...        ...
# 65101  On 6 February 2020, about 50 people, including...          0
# 65102  On 3 February 2020, a group of New Force activ...          0
# 65103  On 2 February 2020, around 100 people, most of...          0
# 65104  On 2 February 2020, an unspecified number of N...          0
# 65105  On 1 February 2020, several youngsters physica...          0
#
#         timestamp iso3
# 0      1664226314  VEN
# 1      1663685720  KOR
# 2      1663685720  CHN
# 3      1663685720  KOR
# 4      1663691322  FRA
# ...           ...  ...
# 65101  1646327097  ITA
# 65102  1660059936  ITA
# 65103  1646327097  ITA
# 65104  1660059936  ITA
# 65105  1646327171  ITA
#
# [65106 rows x 32 columns]
