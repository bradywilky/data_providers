# %% [markdown]
# Another way of looking at the data in terms of usage is how often events are being reported. At a surface level, it may just seem like this analysis shows only how often events are occurring, but this provides additional information on how frequent ACLED is using news sources in creating the dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

base_df = pd.read_csv('../data/acled_covid19.csv')
extd_df = pd.read_csv('../data/EXPANDED_acled_covid19.csv')

# %%
min_dt = min(base_df.event_date)
max_dt = max(base_df.event_date)
labs = pd.date_range(start=min_dt,end=max_dt, freq='Q')
lab_int = np.linspace(0, base_df.event_date.nunique(), len(labs))

# %% [markdown]
# Below is a figure that plots the counts of events reported in the dataset per day. We can see that there are apparent periods of downtime and uptime in terms of how often sources are being used.

# %%
fig, ax = plt.subplots(figsize=(12,10))
all_plot = sns.countplot(x=base_df.event_date)
all_plot.set_xticks(lab_int, labels=labs, rotation=90)
# all_plot.set_xticklabels(all_plot.get_xticks(), rotation = 45)
# Out:
# [<matplotlib.axis.XTick at 0x1795035f2e0>,
#  <matplotlib.axis.XTick at 0x1795035d810>,
#  <matplotlib.axis.XTick at 0x1795371c760>,
#  <matplotlib.axis.XTick at 0x17967ffe350>,
#  <matplotlib.axis.XTick at 0x17967ffeaa0>,
#  <matplotlib.axis.XTick at 0x17967fff1f0>,
#  <matplotlib.axis.XTick at 0x17967fff820>,
#  <matplotlib.axis.XTick at 0x17967ffe6e0>,
#  <matplotlib.axis.XTick at 0x17967fffe50>,
#  <matplotlib.axis.XTick at 0x179680285e0>]
